# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
plt.rcParams.update({'font.size': 14})
import seaborn as sns

# %%
x_axis = [1, 2, 4, 8, 12, 26, 36, 48, 64]

ms = 100
n_tasks = 512
target = [(ms * n_tasks)/i for i in x_axis]
xticks = [1]
for i in range(5, x_axis[-1], 5):
    xticks.append(i)
if xticks[-1] != x_axis[-1]:
    xticks.append(x_axis[-1])

processes_1024_mapping_nonblocking = [51273.98, 25637.337, 12823.965, 6421.347, 4328.487, 2059.878, 1582.8400000000001, 1218.705, 976.293]
processes_1024_mapping_blocking = [51261.082, 25632.035, 12822.116, 6421.399, 4327.843, 2056.698, 1581.172, 1217.387, 972.294]
processes_1024_nomapping_nonblocking = [51240.068, 25621.203, 12818.186, 6422.131, 4320.8279999999995, 2055.423, 1581.432, 1219.606, 989.141]
processes_1024_nomapping_blocking = [51234.268, 25624.96, 12820.204, 6421.173, 4322.083, 2047.437, 1574.858, 1206.435, 992.303]
subintepr_1024_mapping_nonblocking = [51259.286, 25646.62, 12846.931, 6455.354, 4366.307, 2113.462, 1654.917, 1305.591, 1063.714]
subintepr_1024_mapping_blocking = [51250.145, 25646.093, 12846.306, 6456.221, 4362.0380, 2118.348, 1647.562, 1306.82, 1064.52]
subintepr_1024_nomapping_nonblocking = [51248.419, 25645.163, 12853.11, 6461.329, 4371.135, 2116.824, 1630.324, 1300.4850, 1091.291]
subintepr_1024_nomapping_blocking = [51250.077, 25645.012, 12852.751, 6462.53, 4371.669, 2111.287, 1618.797, 1326.948, 1064.208]

# %%
fig, axs = plt.subplots(figsize=(18, 5), dpi=300)
colors = ["#fdd49e", "#fc8d59", "#cc4c02", "#6a51a3"]
linewidth = 2
style = 'o-'
plt.plot(x_axis, processes_1024_mapping_nonblocking, style, label="Processes (Mapping Enabled & Non-Blocking)", linewidth=linewidth, color=colors[2])
plt.plot(x_axis, processes_1024_mapping_blocking, style, label="Processes (Mapping Enabled & Blocking)", linewidth=linewidth, color=colors[3])
plt.plot(x_axis, processes_1024_nomapping_nonblocking, style, label="Processes (Mapping Disabled & Non-Blocking)", linewidth=linewidth, color=colors[0])
plt.plot(x_axis, processes_1024_nomapping_blocking, style, label="Processes (Mapping Disabled & Blocking)", linewidth=linewidth, color=colors[3])
plt.plot(x_axis, subintepr_1024_mapping_nonblocking, style, label="Subinterpreters (Mapping Enabled & Non-Blocking)", linewidth=linewidth, color=colors[0])
plt.plot(x_axis, subintepr_1024_mapping_blocking, style, label="Subinterpreters (Mapping Enabled & Blocking)", linewidth=linewidth, color=colors[0])
plt.plot(x_axis, subintepr_1024_nomapping_nonblocking, style, label="Subinterpreters (Mapping Disabled & Non-Blocking)", linewidth=linewidth, color=colors[0])
plt.plot(x_axis, subintepr_1024_nomapping_blocking, style, label="Subinterpreters (Mapping Disabled & Blocking)", linewidth=linewidth, color=colors[0])
plt.plot(x_axis, target, ls="dotted", label="Target", linewidth=linewidth, color="black")

axs.set_xlabel("Number of workers")
axs.set_ylabel("Time (milliseconds)")
axs.grid()
# Setting the number of ticks
#axs.xaxis.set_major_locator(ticker.MultipleLocator(5))
plt.xticks(xticks, labels=xticks)
#axs.yaxis.set_major_locator(ticker.MultipleLocator(2))
axs.yaxis.set_major_formatter(ticker.ScalarFormatter())
axs.yaxis.set_minor_formatter(ticker.ScalarFormatter())
axs.tick_params(which='minor', length=0)

plt.title('Time over number of workers', fontweight="bold", y=1.05)
plt.legend()
plt.savefig("nomapping-nonblocking-1024bytes", bbox_inches="tight")
plt.show()

# %%
processes_mapping_nonblocking = [54139.373, 27155.321, 13667.015, 7025.488, 4773.465, 3086.494, 3125.298, 3350.342, 4326.939]
processes_mapping_blocking = [54003.181, 27247.694, 13640.834, 7017.875, 4774.72, 3177.937, 3159.25, 3651.627, 3568.257]
processes_nomapping_nonblocking = [53878.917, 27011.031, 13730.187, 6941.789, 4720.199, 3363.242, 3490.617, 3618.636, 3578.52]
processes_nomapping_blocking = [53769.488, 26999.569, 13653.227, 6920.724, 4715.52, 3235.033, 3413.103, 3335.218, 3176.834]
subintepr_mapping_nonblocking = [52284.807, 26198.644, 13135.118, 6607.034, 4484.081, 2184.482, 1710.972, 1377.76, 1590.319]
subintepr_mapping_blocking = [52279.909, 26196.057, 13134.79, 6629.057, 4482.571, 2181.652, 1720.2440, 1391.01, 1548.792]
subintepr_nomapping_nonblocking = [52186.772, 26142.27, 13153.649, 6632.263, 4526.379, 2217.84, 1716.483, 1427.362, 1441.958]
subintepr_nomapping_blocking = [52190.469, 26154.349, 13098.26, 6658.827, 4503.043, 2218.446, 1691.115, 1377.958, 1473.87]

# %%
fig, axs = plt.subplots(figsize=(18, 5), dpi=300)
colors = ["#fdd49e", "#fc8d59", "#cc4c02", "#6a51a3"]
linewidth = 2
style = 'o-'
plt.plot(x_axis, processes_mapping_nonblocking, style, label="Processes (Mapping Enabled & Non-Blocking)", linewidth=linewidth, color=colors[2])
plt.plot(x_axis, processes_mapping_blocking, style, label="Processes (Mapping Enabled & Blocking)", linewidth=linewidth, color=colors[3])
plt.plot(x_axis, processes_nomapping_nonblocking, style, label="Processes (Mapping Disabled & Non-Blocking)", linewidth=linewidth, color=colors[0])
plt.plot(x_axis, processes_nomapping_blocking, style, label="Processes (Mapping Disabled & Blocking)", linewidth=linewidth, color=colors[3])
plt.plot(x_axis, subintepr_mapping_nonblocking, style, label="Subinterpreters (Mapping Enabled & Non-Blocking)", linewidth=linewidth, color=colors[0])
plt.plot(x_axis, subintepr_mapping_blocking, style, label="Subinterpreters (Mapping Enabled & Blocking)", linewidth=linewidth, color=colors[0])
plt.plot(x_axis, subintepr_nomapping_nonblocking, style, label="Subinterpreters (Mapping Disabled & Non-Blocking)", linewidth=linewidth, color=colors[0])
plt.plot(x_axis, subintepr_nomapping_blocking, style, label="Subinterpreters (Mapping Disabled & Blocking)", linewidth=linewidth, color=colors[0])
plt.plot(x_axis, target, ls="dotted", label="Target", linewidth=linewidth, color="black")

axs.set_xlabel("Number of workers")
axs.set_ylabel("Time (milliseconds)")
axs.grid()
# Setting the number of ticks
#axs.xaxis.set_major_locator(ticker.MultipleLocator(5))
plt.xticks(xticks, labels=xticks)
#axs.yaxis.set_major_locator(ticker.MultipleLocator(2))
axs.yaxis.set_major_formatter(ticker.ScalarFormatter())
axs.yaxis.set_minor_formatter(ticker.ScalarFormatter())
axs.tick_params(which='minor', length=0)

plt.title('Time over number of workers', fontweight="bold", y=1.05)
plt.legend()
#plt.savefig("nomapping-nonblocking-1024bytes", bbox_inches="tight")
plt.show()

# %%
fig, axs = plt.subplots(figsize=(18, 5), dpi=300)
colors = ["#fdd49e", "#fc8d59", "#cc4c02", "#6a51a3"]
linewidth = 2
style = 'o-'
plt.plot(x_axis, processes_mapping_nonblocking, style, label="Processes (Mapping Enabled & Non-Blocking)", linewidth=linewidth, color=colors[0])
plt.plot(x_axis, processes_mapping_blocking, style, label="Processes (Mapping Enabled & Blocking)", linewidth=linewidth, color=colors[1])
plt.plot(x_axis, processes_nomapping_nonblocking, style, label="Processes (Mapping Disabled & Non-Blocking)", linewidth=linewidth, color=colors[2])
plt.plot(x_axis, processes_nomapping_blocking, style, label="Processes (Mapping Disabled & Blocking)", linewidth=linewidth, color=colors[3])
plt.plot(x_axis, target, ls="dotted", label="Target", linewidth=linewidth, color="black")

axs.set_xlabel("Number of workers")
axs.set_ylabel("Time (milliseconds)")
axs.grid()
# Setting the number of ticks
#axs.xaxis.set_major_locator(ticker.MultipleLocator(5))
plt.xticks(xticks, labels=xticks)
#axs.yaxis.set_major_locator(ticker.MultipleLocator(2))
axs.yaxis.set_major_formatter(ticker.ScalarFormatter())
axs.yaxis.set_minor_formatter(ticker.ScalarFormatter())
axs.tick_params(which='minor', length=0)
axs.set_xlim(xmin=28)
axs.set_ylim(ymin=0, ymax=4500)

plt.title('Time over number of workers', fontweight="bold", y=1.05)
plt.legend()
#plt.savefig("nomapping-nonblocking-1024bytes", bbox_inches="tight")
plt.show()

# %%
fig, axs = plt.subplots(figsize=(18, 5), dpi=300)
colors = ["#fdd49e", "#fc8d59", "#cc4c02", "#6a51a3"]
linewidth = 2
style = 'o-'
plt.plot(x_axis, subintepr_mapping_nonblocking, style, label="Subinterpreters (Mapping Enabled & Non-Blocking)", linewidth=linewidth, color=colors[0])
plt.plot(x_axis, subintepr_mapping_blocking, style, label="Subinterpreters (Mapping Enabled & Blocking)", linewidth=linewidth, color=colors[1])
plt.plot(x_axis, subintepr_nomapping_nonblocking, style, label="Subinterpreters (Mapping Disabled & Non-Blocking)", linewidth=linewidth, color=colors[2])
plt.plot(x_axis, subintepr_nomapping_blocking, style, label="Subinterpreters (Mapping Disabled & Blocking)", linewidth=linewidth, color=colors[1])
plt.plot(x_axis, target, ls="dotted", label="Target", linewidth=linewidth, color="black")

axs.set_xlabel("Number of tasks")
axs.set_ylabel("Time (milliseconds)")
axs.grid()
# Setting the number of ticks
#axs.xaxis.set_major_locator(ticker.MultipleLocator(5))
plt.xticks(xticks, labels=xticks)
#axs.yaxis.set_major_locator(ticker.MultipleLocator(2))
axs.yaxis.set_major_formatter(ticker.ScalarFormatter())
axs.yaxis.set_minor_formatter(ticker.ScalarFormatter())
axs.tick_params(which='minor', length=0)
axs.set_xlim(xmin=28)
axs.set_ylim(ymin=0, ymax=2250)

plt.title('Time over number of tasks', fontweight="bold", y=1.05)
plt.legend()
#plt.savefig("nomapping-nonblocking-1024bytes", bbox_inches="tight")
plt.show()

# %%
res = dict()
res[1048576] = res.get(1048576, []); res.get(1048576).append((1, 52284.807)) # bytes = 1048576 ms = 100
res[1048576] = res.get(1048576, []); res.get(1048576).append((2, 26198.644)) # bytes = 1048576 ms = 100
res[1048576] = res.get(1048576, []); res.get(1048576).append((4, 13135.118)) # bytes = 1048576 ms = 100
res[1048576] = res.get(1048576, []); res.get(1048576).append((8, 6607.034)) # bytes = 1048576 ms = 100
res[1048576] = res.get(1048576, []); res.get(1048576).append((12, 4484.081)) # bytes = 1048576 ms = 100
res[1048576] = res.get(1048576, []); res.get(1048576).append((26, 2184.482)) # bytes = 1048576 ms = 100
res[1048576] = res.get(1048576, []); res.get(1048576).append((36, 1710.972)) # bytes = 1048576 ms = 100
res[1048576] = res.get(1048576, []); res.get(1048576).append((48, 1377.76)) # bytes = 1048576 ms = 100
res[1048576] = res.get(1048576, []); res.get(1048576).append((64, 1590.319)) # bytes = 1048576 ms = 100

final_result = []
for bytes, lis in res.items():
    row = [bytes, []]
    final_result.append(row)
    for (nw, time_ms) in lis:
        row[1].append(time_ms)
    print(row, end=",\n")
# Out:
# [1048576, [52284.807, 26198.644, 13135.118, 6607.034, 4484.081, 2184.482, 1710.972, 1377.76, 1590.319]],

# %% [raw]
# processes mapping nonblocking
# res[1048576] = res.get(1048576, []); res.get(1048576).append((1, 54139.373)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((2, 27155.321)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((4, 13667.015)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((8, 7025.488)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((12, 4773.465)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((26, 3086.494)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((36, 3125.298)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((48, 3350.342)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((64, 4326.939)) # bytes = 1048576 ms = 100
#
# processes mapping blocking
# res[1048576] = res.get(1048576, []); res.get(1048576).append((1, 54003.181)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((2, 27247.694)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((4, 13640.834)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((8, 7017.875)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((12, 4774.72)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((26, 3177.937)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((36, 3159.25)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((48, 3651.627)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((64, 3568.257)) # bytes = 1048576 ms = 100
#
# processes nomapping blocking
# res[1048576] = res.get(1048576, []); res.get(1048576).append((1, 53769.488)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((2, 26999.569)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((4, 13653.227)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((8, 6920.724)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((12, 4715.52)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((26, 3235.033)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((36, 3413.103)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((48, 3335.218)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((64, 3176.834)) # bytes = 1048576 ms = 100
#
# processes nomapping nonblocking
# res[1048576] = res.get(1048576, []); res.get(1048576).append((1, 53878.917)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((2, 27011.031)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((4, 13730.187)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((8, 6941.789)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((12, 4720.199)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((26, 3363.242)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((36, 3490.617)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((48, 3618.636)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((64, 3578.52)) # bytes = 1048576 ms = 100
#
#
# subints mapping nonblocking
# res[1048576] = res.get(1048576, []); res.get(1048576).append((1, 52284.807)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((2, 26198.644)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((4, 13135.118)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((8, 6607.034)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((12, 4484.081)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((26, 2184.482)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((36, 1710.972)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((48, 1377.76)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((64, 1590.319)) # bytes = 1048576 ms = 100
#
# subints nomapping nonblocking
# res[1048576] = res.get(1048576, []); res.get(1048576).append((1, 52186.772)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((2, 26142.27)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((4, 13153.649)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((8, 6632.263)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((12, 4526.379)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((26, 2217.84)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((36, 1716.483)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((48, 1427.362)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((64, 1441.958)) # bytes = 1048576 ms = 100
#
# subints nomapping blocking
# res[1048576] = res.get(1048576, []); res.get(1048576).append((1, 52190.469)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((2, 26154.349)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((4, 13098.26)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((8, 6658.827)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((12, 4503.043)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((26, 2218.446)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((36, 1691.115)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((48, 1377.958)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((64, 1473.87)) # bytes = 1048576 ms = 100
#
# subints mapping blocking
# res[1048576] = res.get(1048576, []); res.get(1048576).append((1, 52279.909)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((2, 26196.057)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((4, 13134.79)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((8, 6629.057)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((12, 4482.571)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((26, 2181.652)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((36, 1720.2440000000001)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((48, 1391.01)) # bytes = 1048576 ms = 100
# res[1048576] = res.get(1048576, []); res.get(1048576).append((64, 1548.792)) # bytes = 1048576 ms = 100

# %% [raw]
# processes mapping nonblocking
# Running a farm of 1 workers and 512 tasks. Each task is 100ms long and has a size of 1024 bytes. Using processes-based strategy
# res[1024] = res.get(1024, []); res.get(1024).append((1, 51273.98)) # bytes = 1024 ms = 100
# Running a farm of 2 workers and 512 tasks. Each task is 100ms long and has a size of 1024 bytes. Using processes-based strategy
# res[1024] = res.get(1024, []); res.get(1024).append((2, 25637.337)) # bytes = 1024 ms = 100
# Running a farm of 4 workers and 512 tasks. Each task is 100ms long and has a size of 1024 bytes. Using processes-based strategy
# res[1024] = res.get(1024, []); res.get(1024).append((4, 12823.965)) # bytes = 1024 ms = 100
# Running a farm of 8 workers and 512 tasks. Each task is 100ms long and has a size of 1024 bytes. Using processes-based strategy
# res[1024] = res.get(1024, []); res.get(1024).append((8, 6421.347)) # bytes = 1024 ms = 100
# Running a farm of 12 workers and 512 tasks. Each task is 100ms long and has a size of 1024 bytes. Using processes-based strategy
# res[1024] = res.get(1024, []); res.get(1024).append((12, 4328.487)) # bytes = 1024 ms = 100
# Running a farm of 26 workers and 512 tasks. Each task is 100ms long and has a size of 1024 bytes. Using processes-based strategy
# res[1024] = res.get(1024, []); res.get(1024).append((26, 2059.878)) # bytes = 1024 ms = 100
# Running a farm of 36 workers and 512 tasks. Each task is 100ms long and has a size of 1024 bytes. Using processes-based strategy
# res[1024] = res.get(1024, []); res.get(1024).append((36, 1582.8400000000001)) # bytes = 1024 ms = 100
# Running a farm of 48 workers and 512 tasks. Each task is 100ms long and has a size of 1024 bytes. Using processes-based strategy
# res[1024] = res.get(1024, []); res.get(1024).append((48, 1218.705)) # bytes = 1024 ms = 100
# Running a farm of 64 workers and 512 tasks. Each task is 100ms long and has a size of 1024 bytes. Using processes-based strategy
# res[1024] = res.get(1024, []); res.get(1024).append((64, 976.293)) # bytes = 1024 ms = 100
#
# processes mapping blocking
# res[1024] = res.get(1024, []); res.get(1024).append((1, 51261.082)) # bytes = 1024 ms = 100
# res[1024] = res.get(1024, []); res.get(1024).append((2, 25632.035)) # bytes = 1024 ms = 100
# res[1024] = res.get(1024, []); res.get(1024).append((4, 12822.116)) # bytes = 1024 ms = 100
# res[1024] = res.get(1024, []); res.get(1024).append((8, 6421.399)) # bytes = 1024 ms = 100
# res[1024] = res.get(1024, []); res.get(1024).append((12, 4327.843)) # bytes = 1024 ms = 100
# res[1024] = res.get(1024, []); res.get(1024).append((26, 2056.698)) # bytes = 1024 ms = 100
# res[1024] = res.get(1024, []); res.get(1024).append((36, 1581.172)) # bytes = 1024 ms = 100
# res[1024] = res.get(1024, []); res.get(1024).append((48, 1217.387)) # bytes = 1024 ms = 100
# res[1024] = res.get(1024, []); res.get(1024).append((64, 972.294)) # bytes = 1024 ms = 100
#
# processes nomapping blocking
# Running a farm of 1 workers and 512 tasks. Each task is 100ms long and has a size of 1024 bytes. Using processes-based strategy
# res[1024] = res.get(1024, []); res.get(1024).append((1, 51234.268)) # bytes = 1024 ms = 100
# Running a farm of 2 workers and 512 tasks. Each task is 100ms long and has a size of 1024 bytes. Using processes-based strategy
# res[1024] = res.get(1024, []); res.get(1024).append((2, 25624.96)) # bytes = 1024 ms = 100
# Running a farm of 4 workers and 512 tasks. Each task is 100ms long and has a size of 1024 bytes. Using processes-based strategy
# res[1024] = res.get(1024, []); res.get(1024).append((4, 12820.204)) # bytes = 1024 ms = 100
# Running a farm of 8 workers and 512 tasks. Each task is 100ms long and has a size of 1024 bytes. Using processes-based strategy
# res[1024] = res.get(1024, []); res.get(1024).append((8, 6421.173)) # bytes = 1024 ms = 100
# Running a farm of 12 workers and 512 tasks. Each task is 100ms long and has a size of 1024 bytes. Using processes-based strategy
# res[1024] = res.get(1024, []); res.get(1024).append((12, 4322.083)) # bytes = 1024 ms = 100
# Running a farm of 26 workers and 512 tasks. Each task is 100ms long and has a size of 1024 bytes. Using processes-based strategy
# res[1024] = res.get(1024, []); res.get(1024).append((26, 2047.437)) # bytes = 1024 ms = 100
# Running a farm of 36 workers and 512 tasks. Each task is 100ms long and has a size of 1024 bytes. Using processes-based strategy
# res[1024] = res.get(1024, []); res.get(1024).append((36, 1574.858)) # bytes = 1024 ms = 100
# Running a farm of 48 workers and 512 tasks. Each task is 100ms long and has a size of 1024 bytes. Using processes-based strategy
# res[1024] = res.get(1024, []); res.get(1024).append((48, 1206.435)) # bytes = 1024 ms = 100
# Running a farm of 64 workers and 512 tasks. Each task is 100ms long and has a size of 1024 bytes. Using processes-based strategy
# res[1024] = res.get(1024, []); res.get(1024).append((64, 992.303)) # bytes = 1024 ms = 100
#
# processes nomapping nonblocking
# res[1024] = res.get(1024, []); res.get(1024).append((1, 51240.068)) # bytes = 1024 ms = 100
# res[1024] = res.get(1024, []); res.get(1024).append((2, 25621.203)) # bytes = 1024 ms = 100
# res[1024] = res.get(1024, []); res.get(1024).append((4, 12818.186)) # bytes = 1024 ms = 100
# res[1024] = res.get(1024, []); res.get(1024).append((8, 6422.131)) # bytes = 1024 ms = 100
# res[1024] = res.get(1024, []); res.get(1024).append((12, 4320.8279999999995)) # bytes = 1024 ms = 100
# res[1024] = res.get(1024, []); res.get(1024).append((26, 2055.423)) # bytes = 1024 ms = 100
# res[1024] = res.get(1024, []); res.get(1024).append((36, 1581.432)) # bytes = 1024 ms = 100
# res[1024] = res.get(1024, []); res.get(1024).append((48, 1219.606)) # bytes = 1024 ms = 100
# res[1024] = res.get(1024, []); res.get(1024).append((64, 989.141)) # bytes = 1024 ms = 100
#
# subints mapping nonblocking
# res[1024] = res.get(1024, []); res.get(1024).append((1, 51259.286)) # bytes = 1024 ms = 100
# res[1024] = res.get(1024, []); res.get(1024).append((2, 25646.62)) # bytes = 1024 ms = 100
# res[1024] = res.get(1024, []); res.get(1024).append((4, 12846.931)) # bytes = 1024 ms = 100
# res[1024] = res.get(1024, []); res.get(1024).append((8, 6455.354)) # bytes = 1024 ms = 100
# res[1024] = res.get(1024, []); res.get(1024).append((12, 4366.307)) # bytes = 1024 ms = 100
# res[1024] = res.get(1024, []); res.get(1024).append((26, 2113.462)) # bytes = 1024 ms = 100
# res[1024] = res.get(1024, []); res.get(1024).append((36, 1654.917)) # bytes = 1024 ms = 100
# res[1024] = res.get(1024, []); res.get(1024).append((48, 1305.591)) # bytes = 1024 ms = 100
# res[1024] = res.get(1024, []); res.get(1024).append((64, 1063.714)) # bytes = 1024 ms = 100
#
# subints nomapping nonblocking
# res[1024] = res.get(1024, []); res.get(1024).append((1, 51248.419)) # bytes = 1024 ms = 100
# res[1024] = res.get(1024, []); res.get(1024).append((2, 25645.163)) # bytes = 1024 ms = 100
# res[1024] = res.get(1024, []); res.get(1024).append((4, 12853.11)) # bytes = 1024 ms = 100
# res[1024] = res.get(1024, []); res.get(1024).append((8, 6461.329)) # bytes = 1024 ms = 100
# res[1024] = res.get(1024, []); res.get(1024).append((12, 4371.135)) # bytes = 1024 ms = 100
# res[1024] = res.get(1024, []); res.get(1024).append((26, 2116.824)) # bytes = 1024 ms = 100
# res[1024] = res.get(1024, []); res.get(1024).append((36, 1630.324)) # bytes = 1024 ms = 100
# res[1024] = res.get(1024, []); res.get(1024).append((48, 1300.4850000000001)) # bytes = 1024 ms = 100
# res[1024] = res.get(1024, []); res.get(1024).append((64, 1091.291)) # bytes = 1024 ms = 100
#
# subints nomapping blocking
# res[1024] = res.get(1024, []); res.get(1024).append((1, 51250.077)) # bytes = 1024 ms = 100
# res[1024] = res.get(1024, []); res.get(1024).append((2, 25645.012)) # bytes = 1024 ms = 100
# res[1024] = res.get(1024, []); res.get(1024).append((4, 12852.751)) # bytes = 1024 ms = 100
# res[1024] = res.get(1024, []); res.get(1024).append((8, 6462.53)) # bytes = 1024 ms = 100
# res[1024] = res.get(1024, []); res.get(1024).append((12, 4371.669)) # bytes = 1024 ms = 100
# res[1024] = res.get(1024, []); res.get(1024).append((26, 2111.287)) # bytes = 1024 ms = 100
# res[1024] = res.get(1024, []); res.get(1024).append((36, 1618.797)) # bytes = 1024 ms = 100
# res[1024] = res.get(1024, []); res.get(1024).append((48, 1326.9479999999999)) # bytes = 1024 ms = 100
# res[1024] = res.get(1024, []); res.get(1024).append((64, 1064.208)) # bytes = 1024 ms = 100
#
# subints mapping blocking
# res[1024] = res.get(1024, []); res.get(1024).append((1, 51250.145)) # bytes = 1024 ms = 100
# res[1024] = res.get(1024, []); res.get(1024).append((2, 25646.093)) # bytes = 1024 ms = 100
# res[1024] = res.get(1024, []); res.get(1024).append((4, 12846.306)) # bytes = 1024 ms = 100
# res[1024] = res.get(1024, []); res.get(1024).append((8, 6456.221)) # bytes = 1024 ms = 100
# res[1024] = res.get(1024, []); res.get(1024).append((12, 4362.0380000000005)) # bytes = 1024 ms = 100
# res[1024] = res.get(1024, []); res.get(1024).append((26, 2118.348)) # bytes = 1024 ms = 100
# res[1024] = res.get(1024, []); res.get(1024).append((36, 1647.562)) # bytes = 1024 ms = 100
# res[1024] = res.get(1024, []); res.get(1024).append((48, 1306.82)) # bytes = 1024 ms = 100
# res[1024] = res.get(1024, []); res.get(1024).append((64, 1064.52)) # bytes = 1024 ms = 100
