# %%
import matplotlib.pyplot as plt
ms = 1
n_tasks = 512
subtitle = f"n_tasks = {n_tasks}, each task is {ms}ms"
x_axis_workers = [1, 2, 4, 8, 10, 12, 16, 20, 26, 30, 36, 42, 48, 54, 60, 64]
target = [(ms * n_tasks)/i for i in x_axis_workers]
print(target)
# Out:
# [512.0, 256.0, 128.0, 64.0, 51.2, 42.666666666666664, 32.0, 25.6, 19.692307692307693, 17.066666666666666, 14.222222222222221, 12.19047619047619, 10.666666666666666, 9.481481481481481, 8.533333333333333, 8.0]

# %% [markdown]
# # Processes

# %%
processes = [
    [100, [594.023, 327.465, 165.722, 268.447, 241.903, 203.809, 184.293, 180.421, 188.936, 408.271, 358.702, 524.578, 373.845, 432.682, 650.524, 901.751]], 
    [512, [596.482, 328.008, 166.059, 263.161, 233.017, 205.168, 248.344, 341.13, 225.316, 388.749, 463.015, 388.606, 430.948, 688.629, 527.461, 641.993]], 
    [1024, [600.409, 342.756, 168.218, 262.012, 240.622, 248.837, 171.218, 344.999, 370.24, 399.06, 370.36, 585.407, 475.506, 639.712, 798.006, 493.631]], 
    [8192, [638.531, 340.369, 192.138, 293.863, 236.156, 296.19, 331.129, 206.314, 371.699, 230.12, 515.999, 549.209, 692.733, 612.84, 514.974, 463.505]], 
    [32768, [744.463, 396.528, 238.906, 326.015, 284.802, 324.618, 414.204, 324.608, 307.748, 530.545, 413.474, 635.486, 773.788, 741.129, 983.586, 1019.85]], 
    [524288, [3164.493, 2722.592, 2602.804, 2596.881, 2621.381, 2673.671, 2748.343, 2796.654, 2702.031, 2878.81, 2970.891, 3022.855, 3215.699, 3492.516, 3362.755, 4762.434]], 
    [1048576, [5879.828, 5464.407, 5262.718, 5231.66, 5250.425, 5192.212, 5202.625, 5286.946, 5275.15, 5221.181, 5644.218, 5639.372, 6010.727, 5639.026, 6269.688, 8544.909]]
]

# %%
fig, axs = plt.subplots(figsize=(18, 5), dpi=300)
axs.grid()
# Setting the number of ticks
plt.locator_params(axis='x', nbins=len(x_axis_workers)) 
plt.locator_params(axis='y', nbins=24)
plt.plot(x_axis_workers, target, ls="dotted", label="Target", color="grey")
for res in processes:
    kb = 0.1 if res[0] == 100 else res[0] / 1024
    plt.plot(x_axis_workers, res[1], label=f"Processes ({kb} KB)")

axs.set_xlabel("number of workers")
axs.set_ylabel("time (msec)")
axs.set_ylim(ymin=0)

plt.suptitle('[Processes] Time over number of workers', y=0.97, fontweight="bold")
plt.title(subtitle)
plt.legend()
#savefig("stream_service_time")
plt.show()

# %% [markdown]
# # Subinterpreters

# %%
subinterpreters = [[100, [592.347, 346.757, 239.676, 212.258, 221.153, 216.109, 250.438, 286.697, 323.865, 381.116, 417.58, 480.236, 521.298, 571.441, 623.912, 676.931]], [512, [592.786, 346.043, 237.781, 212.801, 219.988, 217.847, 250.628, 273.898, 318.102, 363.064, 424.052, 477.949, 537.418, 572.023, 634.257, 667.525]], [1024, [592.449, 338.185, 238.549, 202.744, 222.873, 226.07, 256.166, 286.346, 324.447, 368.916, 410.389, 482.752, 520.546, 592.519, 637.577, 684.923]], [8192, [587.784, 341.62, 239.392, 212.002, 214.811, 224.734, 247.126, 284.246, 332.417, 366.767, 424.202, 465.358, 557.33, 595.281, 623.261, 675.115]], [32768, [592.656, 337.468, 238.36, 205.344, 220.309, 217.586, 242.851, 283.058, 325.419, 361.971, 425.681, 469.573, 535.379, 571.459, 623.77, 668.537]], [524288, [584.368, 342.838, 226.236, 210.797, 208.193, 223.032, 242.121, 266.373, 325.808, 366.446, 409.467, 466.517, 516.665, 563.239, 623.535, 667.262]], [1048576, [588.298, 346.54, 238.419, 210.186, 214.835, 226.247, 247.294, 283.942, 321.454, 371.69, 409.24, 467.783, 524.904, 589.89, 622.996, 666.984]]]

# %%
fig, axs = plt.subplots(figsize=(18, 5), dpi=300)
axs.grid()
# Setting the number of ticks
plt.locator_params(axis='x', nbins=len(x_axis_workers)) 
plt.locator_params(axis='y', nbins=24)
plt.plot(x_axis_workers, target, ls="dotted", label="Target", color="grey")
for res in subinterpreters:
    kb = 0.1 if res[0] == 100 else res[0] / 1024
    plt.plot(x_axis_workers, res[1], label=f"Subinterpreters ({kb} KB)")

axs.set_xlabel("number of workers")
axs.set_ylabel("time (msec)")
axs.set_ylim(ymin=0)

plt.suptitle('[Subinterpreters] Time over number of workers', y=0.97, fontweight="bold")
plt.title(subtitle)
plt.legend()
#savefig("stream_service_time")
plt.show()

# %% [markdown]
# # Comparison

# %%
for i in range(len(subinterpreters)):
    fig, axs = plt.subplots(figsize=(18, 5), dpi=300)
    axs.grid()
    # Setting the number of ticks
    plt.locator_params(axis='x', nbins=len(x_axis_workers)) 
    plt.locator_params(axis='y', nbins=24)
    kb_proc = 0.1 if processes[i][0] == 100 else processes[i][0] / 1024
    kb_sub = 0.1 if subinterpreters[i][0] == 100 else subinterpreters[i][0] / 1024
    plt.plot(x_axis_workers, processes[i][1], label=f"Processes ({kb_proc} KB)")
    plt.plot(x_axis_workers, subinterpreters[i][1], label=f"Subinterpreters ({kb_sub} KB)")
    plt.plot(x_axis_workers, target, ls="dotted", label="Target", color="grey")

    axs.set_xlabel("number of workers")
    axs.set_ylabel("time (msec)")
    axs.set_ylim(ymin=0)#, ymax=8500)

    plt.suptitle('Time over number of workers', y=0.97, fontweight="bold")
    plt.title(f"{subtitle}, task size = {kb_proc} KB")
    plt.legend()
    #savefig("stream_service_time")
    plt.show()

# %%
res = dict()
res[100] = res.get(100, []); res.get(100).append((1, 565.924)) # bytes = 100 ms = 1
res[512] = res.get(512, []); res.get(512).append((1, 566.184)) # bytes = 512 ms = 1
res[1024] = res.get(1024, []); res.get(1024).append((1, 568.693)) # bytes = 1024 ms = 1
res[8192] = res.get(8192, []); res.get(8192).append((1, 585.319)) # bytes = 8192 ms = 1
res[32768] = res.get(32768, []); res.get(32768).append((1, 624.42)) # bytes = 32768 ms = 1
res[524288] = res.get(524288, []); res.get(524288).append((1, 1721.187)) # bytes = 524288 ms = 1
res[1048576] = res.get(1048576, []); res.get(1048576).append((1, 3079.436)) # bytes = 1048576 ms = 1
res[100] = res.get(100, []); res.get(100).append((2, 301.594)) # bytes = 100 ms = 1
res[512] = res.get(512, []); res.get(512).append((2, 292.126)) # bytes = 512 ms = 1
res[1024] = res.get(1024, []); res.get(1024).append((2, 293.321)) # bytes = 1024 ms = 1
res[8192] = res.get(8192, []); res.get(8192).append((2, 302.077)) # bytes = 8192 ms = 1
res[32768] = res.get(32768, []); res.get(32768).append((2, 322.834)) # bytes = 32768 ms = 1
res[524288] = res.get(524288, []); res.get(524288).append((2, 1262.233)) # bytes = 524288 ms = 1
res[1048576] = res.get(1048576, []); res.get(1048576).append((2, 2717.058)) # bytes = 1048576 ms = 1
res[100] = res.get(100, []); res.get(100).append((4, 157.407)) # bytes = 100 ms = 1
res[512] = res.get(512, []); res.get(512).append((4, 157.556)) # bytes = 512 ms = 1
res[1024] = res.get(1024, []); res.get(1024).append((4, 158.068)) # bytes = 1024 ms = 1
res[8192] = res.get(8192, []); res.get(8192).append((4, 163.517)) # bytes = 8192 ms = 1
res[32768] = res.get(32768, []); res.get(32768).append((4, 176.391)) # bytes = 32768 ms = 1
res[524288] = res.get(524288, []); res.get(524288).append((4, 1194.0140000000001)) # bytes = 524288 ms = 1
res[1048576] = res.get(1048576, []); res.get(1048576).append((4, 2491.8450000000003)) # bytes = 1048576 ms = 1
res[100] = res.get(100, []); res.get(100).append((8, 114.802)) # bytes = 100 ms = 1
res[512] = res.get(512, []); res.get(512).append((8, 95.444)) # bytes = 512 ms = 1
res[1024] = res.get(1024, []); res.get(1024).append((8, 94.42)) # bytes = 1024 ms = 1
res[8192] = res.get(8192, []); res.get(8192).append((8, 118.765)) # bytes = 8192 ms = 1
res[32768] = res.get(32768, []); res.get(32768).append((8, 143.707)) # bytes = 32768 ms = 1
res[524288] = res.get(524288, []); res.get(524288).append((8, 1206.163)) # bytes = 524288 ms = 1
res[1048576] = res.get(1048576, []); res.get(1048576).append((8, 2458.465)) # bytes = 1048576 ms = 1
res[100] = res.get(100, []); res.get(100).append((10, 123.458)) # bytes = 100 ms = 1
res[512] = res.get(512, []); res.get(512).append((10, 93.958)) # bytes = 512 ms = 1
res[1024] = res.get(1024, []); res.get(1024).append((10, 84.225)) # bytes = 1024 ms = 1
res[8192] = res.get(8192, []); res.get(8192).append((10, 97.391)) # bytes = 8192 ms = 1
res[32768] = res.get(32768, []); res.get(32768).append((10, 165.432)) # bytes = 32768 ms = 1
res[524288] = res.get(524288, []); res.get(524288).append((10, 1255.734)) # bytes = 524288 ms = 1
res[1048576] = res.get(1048576, []); res.get(1048576).append((10, 2445.71)) # bytes = 1048576 ms = 1
res[100] = res.get(100, []); res.get(100).append((12, 125.985)) # bytes = 100 ms = 1
res[512] = res.get(512, []); res.get(512).append((12, 79.466)) # bytes = 512 ms = 1
res[1024] = res.get(1024, []); res.get(1024).append((12, 115.318)) # bytes = 1024 ms = 1
res[8192] = res.get(8192, []); res.get(8192).append((12, 137.173)) # bytes = 8192 ms = 1
res[32768] = res.get(32768, []); res.get(32768).append((12, 167.012)) # bytes = 32768 ms = 1
res[524288] = res.get(524288, []); res.get(524288).append((12, 1266.483)) # bytes = 524288 ms = 1
res[1048576] = res.get(1048576, []); res.get(1048576).append((12, 2537.869)) # bytes = 1048576 ms = 1
res[100] = res.get(100, []); res.get(100).append((16, 81.406)) # bytes = 100 ms = 1
res[512] = res.get(512, []); res.get(512).append((16, 108.618)) # bytes = 512 ms = 1
res[1024] = res.get(1024, []); res.get(1024).append((16, 108.187)) # bytes = 1024 ms = 1
res[8192] = res.get(8192, []); res.get(8192).append((16, 121.027)) # bytes = 8192 ms = 1
res[32768] = res.get(32768, []); res.get(32768).append((16, 149.909)) # bytes = 32768 ms = 1
res[524288] = res.get(524288, []); res.get(524288).append((16, 1243.509)) # bytes = 524288 ms = 1
res[1048576] = res.get(1048576, []); res.get(1048576).append((16, 2474.677)) # bytes = 1048576 ms = 1
res[100] = res.get(100, []); res.get(100).append((20, 89.122)) # bytes = 100 ms = 1
res[512] = res.get(512, []); res.get(512).append((20, 93.421)) # bytes = 512 ms = 1
res[1024] = res.get(1024, []); res.get(1024).append((20, 97.575)) # bytes = 1024 ms = 1
res[8192] = res.get(8192, []); res.get(8192).append((20, 120.188)) # bytes = 8192 ms = 1
res[32768] = res.get(32768, []); res.get(32768).append((20, 162.358)) # bytes = 32768 ms = 1
res[524288] = res.get(524288, []); res.get(524288).append((20, 1259.863)) # bytes = 524288 ms = 1
res[1048576] = res.get(1048576, []); res.get(1048576).append((20, 2491.683)) # bytes = 1048576 ms = 1
res[100] = res.get(100, []); res.get(100).append((26, 108.405)) # bytes = 100 ms = 1
res[512] = res.get(512, []); res.get(512).append((26, 109.606)) # bytes = 512 ms = 1
res[1024] = res.get(1024, []); res.get(1024).append((26, 285.787)) # bytes = 1024 ms = 1
res[8192] = res.get(8192, []); res.get(8192).append((26, 138.308)) # bytes = 8192 ms = 1
res[32768] = res.get(32768, []); res.get(32768).append((26, 183.885)) # bytes = 32768 ms = 1
res[524288] = res.get(524288, []); res.get(524288).append((26, 1324.671)) # bytes = 524288 ms = 1
res[1048576] = res.get(1048576, []); res.get(1048576).append((26, 2533.1130000000003)) # bytes = 1048576 ms = 1
res[100] = res.get(100, []); res.get(100).append((30, 118.399)) # bytes = 100 ms = 1
res[512] = res.get(512, []); res.get(512).append((30, 122.853)) # bytes = 512 ms = 1
res[1024] = res.get(1024, []); res.get(1024).append((30, 363.14)) # bytes = 1024 ms = 1
res[8192] = res.get(8192, []); res.get(8192).append((30, 401.763)) # bytes = 8192 ms = 1
res[32768] = res.get(32768, []); res.get(32768).append((30, 198.8)) # bytes = 32768 ms = 1
res[524288] = res.get(524288, []); res.get(524288).append((30, 1315.505)) # bytes = 524288 ms = 1
res[1048576] = res.get(1048576, []); res.get(1048576).append((30, 2553.2690000000002)) # bytes = 1048576 ms = 1
res[100] = res.get(100, []); res.get(100).append((36, 377.688)) # bytes = 100 ms = 1
res[512] = res.get(512, []); res.get(512).append((36, 154.089)) # bytes = 512 ms = 1
res[1024] = res.get(1024, []); res.get(1024).append((36, 153.77)) # bytes = 1024 ms = 1
res[8192] = res.get(8192, []); res.get(8192).append((36, 482.727)) # bytes = 8192 ms = 1
res[32768] = res.get(32768, []); res.get(32768).append((36, 233.353)) # bytes = 32768 ms = 1
res[524288] = res.get(524288, []); res.get(524288).append((36, 1642.03)) # bytes = 524288 ms = 1
res[1048576] = res.get(1048576, []); res.get(1048576).append((36, 2516.706)) # bytes = 1048576 ms = 1
res[100] = res.get(100, []); res.get(100).append((42, 171.901)) # bytes = 100 ms = 1
res[512] = res.get(512, []); res.get(512).append((42, 421.377)) # bytes = 512 ms = 1
res[1024] = res.get(1024, []); res.get(1024).append((42, 483.86)) # bytes = 1024 ms = 1
res[8192] = res.get(8192, []); res.get(8192).append((42, 581.465)) # bytes = 8192 ms = 1
res[32768] = res.get(32768, []); res.get(32768).append((42, 582.179)) # bytes = 32768 ms = 1
res[524288] = res.get(524288, []); res.get(524288).append((42, 1855.0259999999998)) # bytes = 524288 ms = 1
res[1048576] = res.get(1048576, []); res.get(1048576).append((42, 2599.7619999999997)) # bytes = 1048576 ms = 1
res[100] = res.get(100, []); res.get(100).append((48, 665.05)) # bytes = 100 ms = 1
res[512] = res.get(512, []); res.get(512).append((48, 616.821)) # bytes = 512 ms = 1
res[1024] = res.get(1024, []); res.get(1024).append((48, 210.175)) # bytes = 1024 ms = 1
res[8192] = res.get(8192, []); res.get(8192).append((48, 658.712)) # bytes = 8192 ms = 1
res[32768] = res.get(32768, []); res.get(32768).append((48, 304.473)) # bytes = 32768 ms = 1
res[524288] = res.get(524288, []); res.get(524288).append((48, 1954.848)) # bytes = 524288 ms = 1
res[1048576] = res.get(1048576, []); res.get(1048576).append((48, 3185.167)) # bytes = 1048576 ms = 1
res[100] = res.get(100, []); res.get(100).append((54, 213.962)) # bytes = 100 ms = 1
res[512] = res.get(512, []); res.get(512).append((54, 218.468)) # bytes = 512 ms = 1
res[1024] = res.get(1024, []); res.get(1024).append((54, 747.222)) # bytes = 1024 ms = 1
res[8192] = res.get(8192, []); res.get(8192).append((54, 279.206)) # bytes = 8192 ms = 1
res[32768] = res.get(32768, []); res.get(32768).append((54, 345.965)) # bytes = 32768 ms = 1
res[524288] = res.get(524288, []); res.get(524288).append((54, 1478.2269999999999)) # bytes = 524288 ms = 1
res[1048576] = res.get(1048576, []); res.get(1048576).append((54, 2684.956)) # bytes = 1048576 ms = 1
res[100] = res.get(100, []); res.get(100).append((60, 239.136)) # bytes = 100 ms = 1
res[512] = res.get(512, []); res.get(512).append((60, 263.967)) # bytes = 512 ms = 1
res[1024] = res.get(1024, []); res.get(1024).append((60, 282.598)) # bytes = 1024 ms = 1
res[8192] = res.get(8192, []); res.get(8192).append((60, 332.994)) # bytes = 8192 ms = 1
res[32768] = res.get(32768, []); res.get(32768).append((60, 417.515)) # bytes = 32768 ms = 1
res[524288] = res.get(524288, []); res.get(524288).append((60, 1561.603)) # bytes = 524288 ms = 1
res[1048576] = res.get(1048576, []); res.get(1048576).append((60, 2848.067)) # bytes = 1048576 ms = 1
res[100] = res.get(100, []); res.get(100).append((64, 664.398)) # bytes = 100 ms = 1
res[512] = res.get(512, []); res.get(512).append((64, 273.333)) # bytes = 512 ms = 1
res[1024] = res.get(1024, []); res.get(1024).append((64, 592.782)) # bytes = 1024 ms = 1
res[8192] = res.get(8192, []); res.get(8192).append((64, 660.515)) # bytes = 8192 ms = 1
res[32768] = res.get(32768, []); res.get(32768).append((64, 780.347)) # bytes = 32768 ms = 1
res[524288] = res.get(524288, []); res.get(524288).append((64, 2560.21)) # bytes = 524288 ms = 1
res[1048576] = res.get(1048576, []); res.get(1048576).append((64, 3642.7309999999998)) # bytes = 1048576 ms = 1

final_result = []
for bytes, lis in res.items():
    row = [bytes, []]
    final_result.append(row)
    for (nw, time_ms) in lis:
        row[1].append(time_ms)
print(final_result)
# Out:
# [[100, [565.924, 301.594, 157.407, 114.802, 123.458, 125.985, 81.406, 89.122, 108.405, 118.399, 377.688, 171.901, 665.05, 213.962, 239.136, 664.398]], [512, [566.184, 292.126, 157.556, 95.444, 93.958, 79.466, 108.618, 93.421, 109.606, 122.853, 154.089, 421.377, 616.821, 218.468, 263.967, 273.333]], [1024, [568.693, 293.321, 158.068, 94.42, 84.225, 115.318, 108.187, 97.575, 285.787, 363.14, 153.77, 483.86, 210.175, 747.222, 282.598, 592.782]], [8192, [585.319, 302.077, 163.517, 118.765, 97.391, 137.173, 121.027, 120.188, 138.308, 401.763, 482.727, 581.465, 658.712, 279.206, 332.994, 660.515]], [32768, [624.42, 322.834, 176.391, 143.707, 165.432, 167.012, 149.909, 162.358, 183.885, 198.8, 233.353, 582.179, 304.473, 345.965, 417.515, 780.347]], [524288, [1721.187, 1262.233, 1194.0140000000001, 1206.163, 1255.734, 1266.483, 1243.509, 1259.863, 1324.671, 1315.505, 1642.03, 1855.0259999999998, 1954.848, 1478.2269999999999, 1561.603, 2560.21]], [1048576, [3079.436, 2717.058, 2491.8450000000
# ...
